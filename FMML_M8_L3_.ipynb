# %% [markdown]
# <a href="https://colab.research.google.com/github/Sudha8978/LABS-FMML/blob/main/FMML_M8_L3_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-30 12:51:21--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  93.5MB/s    in 0.7s
#
# 2025-03-30 12:51:24 (93.5 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 21973   1211.0932v1  We study the mixtures of factorizing probabili...  stat
# 18903   1301.2259v1  We propose a new directed graphical representa...    cs
# 22263  1510.08512v1  Gaussian Graphical Models (GGMs) are popular t...  stat
# 171    1711.01577v3  Long Short-Term Memory (LSTM) is a popular app...  stat
# 18671   1108.3711v2  UCT, a state-of-the art algorithm for Monte Ca...    cs
# ...             ...                                                ...   ...
# 37936   1204.1664v3  Herding and kernel herding are deterministic m...  stat
# 10347   1209.6004v1  We develop a model of issue-specific voting be...  stat
# 39399  1602.04981v1  Navigation in an unknown environment consists ...    cs
# 18954   1301.3869v1  Many large MDPs can be represented compactly u...    cs
# 22146  1504.06026v1  We consider the problem of estimating undirect...  stat
#
#                                                    title  year  \
# 21973      Kernels and Submodels of Deep Belief Networks  2012
# 18903  UCP-Networks: A Directed Graphical Representat...  2013
# 22263  Robust Gaussian Graphical Modeling with the Tr...  2015
# 171    Wider and Deeper, Cheaper and Faster: Tensoriz...  2017
# 18671  Doing Better Than UCT: Rational Monte Carlo Sa...  2011
# ...                                                  ...   ...
# 37936  Optimally-Weighted Herding is Bayesian Quadrature  2012
# 10347               The Issue-Adjusted Ideal Point Model  2012
# 39399  Optimizing Gaze Direction in a Visual Navigati...  2016
# 18954                 Policy Iteration for Factored MDPs  2013
# 22146  Graphical Fermat's Principle and Triangle-Free...  2015
#
#                                                 keywords
# 21973  [factorizing, probability, distributions, repr...
# 18903  [graphical, representation, functions, graphic...
# 22263  [graphical, structures, applications, discover...
# 171    [recurrent, information, increased, introduces...
# 18671  [algorithm, minimizes, accumulated, cumulative...
# ...                                                  ...
# 37936  [deterministic, summarise, probability, distri...
# 10347  [lawmakers, providing, exploratory, correlated...
# 39399  [navigation, environment, separable, collectin...
# 18954  [represented, compactly, structure, structure,...
# 22146  [estimating, undirected, dimensional, distribu...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 21973    [factorizing, probability, distributions, repr...
# 18903    [graphical, representation, functions, graphic...
# 22263    [graphical, structures, applications, discover...
# 171      [recurrent, information, increased, introduces...
# 18671    [algorithm, minimizes, accumulated, cumulative...
#                                ...
# 27303    [alignment, diagnostics, procedure, treatment,...
# 35988    [constraint, programming, constraint, satisfac...
# 22543    [community, detection, parametrized, normalize...
# 13105    [optimization, lookahead, objective, decompose...
# 31604    [descriptors, attention, discriminative, abili...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8798 words.
# Out of those 4590 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c15aaf4b-2031-4317-9f6e-954a38ad2d3e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c15aaf4b-2031-4317-9f6e-954a38ad2d3e")) {                    Plotly.newPlot(                        "c15aaf4b-2031-4317-9f6e-954a38ad2d3e",                        [{"x":["realizable","geometric","transitions","distributions","distributed","representations","including","stochastic","properties","depending","probability","submodels","represented","combinatorial","exponential","connections","perspective","approximation","parameters","factorizing","preference","graphical","reflecting","demonstrate","efficient","interpretation","specified","statements","threshold","semantics","elicitation","dependence","generalized","dominance","utilities","representation","advantage","questioning","optimization","conditional","furthermore","underlying","decomposes","computation","functions","procedure","interactive","constraints","experiments","approaches","simulated","complemented","applications","mechanism","dimensional","discovery","structures","interactions","estimation","expression","statistical","theoretical","regression","estimator","guarantees","distribution","additional","increasing","computations","potential","information","introduces","increased","implicitly","recurrent","challenging","convolution","conducted","locations","increases","efficiently","alternative","different","asymptotic","algorithms","minimizes","reasoning","minimization","minimized","algorithm","outperforms","empirically","accumulated","techniques","introducing","cumulative","gradients","descriptive","household","independently","eventually","hierarchical","captioning","exploiting","conditioning","overlapping","interpretable","behaviour","disregards","univariate","variation","regularization","spontaneous","organization","diagnosis","classification","regularized","prediction","framework","activation","typically","important","multivariate","variables","population","classically","principles","behavioural","informative","predictive","extraction","difficult","extracted","dimensionality","parametric","challenge","interpret","structure","functional","selecting","generalization","prioritizing","benchmark","hyperplane","mechanisms","discriminative","classifier","comparable","minimizing","demonstrating","improving","selection","parsimonious","comparison","dimension","importance","complexity","attributes","developing","combination","overfitting","effective","searching","identifying","contributes","vocabulary","described","methodology","compilation","dictionaries","concentration","characteristics","quantitative","perekhresni","following","frequency","correlation","exclusiveness","dictionary","solutions","automatic","characters","advocates","replacing","practical","incomplete","processing","attention","recordings","pipelines","independent","integration","contribution","shortcomings","predictions","competitive","recognition","transcriptions","achieving","intuitive"],"y":[2,94,10,119,103,242,235,126,201,38,184,1,104,43,47,44,64,112,240,3,20,50,6,559,390,68,34,12,38,99,5,32,67,10,6,374,74,1,308,104,150,112,9,125,228,121,43,151,588,415,71,1,436,111,166,62,135,66,220,50,156,158,109,17,57,220,96,111,33,149,678,55,41,15,140,259,51,74,51,51,145,88,786,15,601,20,138,64,15,793,268,79,6,368,56,9,36,18,6,42,11,119,10,69,17,26,22,32,4,3,61,89,9,13,49,489,38,245,566,41,109,394,19,155,46,4,46,3,46,70,150,148,108,68,41,156,22,328,38,34,111,2,212,4,47,108,139,88,45,41,118,173,5,140,65,75,221,76,58,146,26,239,30,91,15,26,72,48,9,21,9,105,87,2,87,52,72,2,52,144,200,32,3,13,150,43,306,166,11,14,150,42,68,17,90,113,389,6,90,38],"type":"bar"},{"x":["realizable","geometric","transitions","distributions","distribute ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4590,), (4590, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7933333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>SPLODE</span> <span style=''>Semi</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Probabilistic</span> <span style=''>Point</span> <span style=''>and</span> <span style=''>Line</span> <span style=''>Odometry</span> <span style=''>with</span> <span style=''>Depth</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Estimation</span> <span style=''>from</span> <span style=''>RGB</span> <span style=''>D</span> <span style=''>Camera</span> <span style=''>Motion</span> <br/><br/><span style=''>Active</span> <span style=''>depth</span> <span style=''>cameras</span> <span style=''>suffer</span> <span style=''>from</span> <span style=''>several</span> <span style='background-color:rgba(0, 255, 0, 0.325301204819277);'>limitations</span> <span style=''>which</span> <span style=''>cause</span> <span style='background-color:rgba(0, 255, 0, 0.40983606557377045);'>incomplete</span> <span style=''>and</span> <span style=''>noisy</span> <span style=''>depth</span> <span style=''>maps</span> <span style=''>and</span> <span style=''>may</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consequently</span> <span style=''>affect</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>RGB</span> <span style=''>D</span> <span style=''>Odometry</span> <span style=''>To</span> <span style=''>address</span> <span style=''>this</span> <span style=''>issue</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>a</span> <span style=''>visual</span> <span style=''>odometry</span> <span style=''>method</span> <span style=''>based</span> <span style=''>on</span> <span style=''>point</span> <span style=''>and</span> <span style=''>line</span> <span style=''>features</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>leverages</span> <span style=''>both</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measurements</span> <span style=''>from</span> <span style=''>a</span> <span style=''>depth</span> <span style=''>sensor</span> <span style=''>and</span> <span style=''>depth</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimates</span> <span style=''>from</span> <span style=''>camera</span> <span style=''>motion</span> <span style=''>Depth</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimates</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generated</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666666);'>continuously</span> <span style=''>by</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>depth</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>both</span> <span style=''>types</span> <span style=''>of</span> <span style=''>features</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>compensate</span> <span style=''>for</span> <span style=''>the</span> <span style=''>lack</span> <span style=''>of</span> <span style=''>depth</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measurements</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>inaccurate</span> <span style=''>feature</span> <span style=''>depth</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>associations</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>models</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>explicitly</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style=''>of</span> <span style=''>triangulating</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Regularizing</span> <span style=''>Model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Complexity</span> <span style=''>and</span> <span style=''>Label</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Structure</span> <span style=''>for</span> <span style=''>Multi</span> <span style=''>Label</span> <span style=''>Text</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Classification</span> <br/><br/><span style=''>Multi</span> <span style=''>label</span> <span style=''>text</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>is</span> <span style=''>a</span> <span style=''>popular</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>task</span> <span style=''>where</span> <span style=''>each</span> <span style=''>document</span> <span style=''>is</span> <span style=''>assigned</span> <span style=''>with</span> <span style=''>multiple</span> <span style=''>relevant</span> <span style=''>labels</span> <span style=''>This</span> <span style=''>task</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>due</span> <span style=''>to</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>features</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correlated</span> <span style=''>labels</span> <span style=''>Multi</span> <span style=''>label</span> <span style=''>text</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>need</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>carefully</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularized</span> <span style=''>to</span> <span style=''>prevent</span> <span style=''>the</span> <span style=''>severe</span> <span style=''>over</span> <span style=''>fitting</span> <span style=''>in</span> <span style=''>the</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>space</span> <span style=''>and</span> <span style=''>also</span> <span style=''>need</span> <span style=''>to</span> <span style=''>take</span> <span style=''>into</span> <span style=''>account</span> <span style=''>label</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependencies</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>make</span> <span style=''>accurate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictions</span> <span style=''>under</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>uncertainty</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>improvement</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>carefully</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularizing</span> <span style=''>the</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>during</span> <span style=''>training</span> <span style=''>phase</span> <span style=''>and</span> <span style=''>also</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularizing</span> <span style=''>the</span> <span style=''>label</span> <span style=''>search</span> <span style=''>space</span> <span style=''>during</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>phase</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Specifically</ ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>MMSE</span> <span style=''>and</span> <span style=''>MAP</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Denoising</span> <span style=''>Under</span> <span style=''>Sparse</span> <span style='background-color:rgba(0, 255, 0, 0.4166666666666667);'>Representation</span> <span style=''>Modeling</span> <span style=''>Over</span> <span style=''>a</span> <span style=''>Unitary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dictionary</span> <br/><br/><span style=''>Among</span> <span style=''>the</span> <span style=''>many</span> <span style=''>ways</span> <span style=''>to</span> <span style=''>model</span> <span style=''>signals</span> <span style=''>a</span> <span style=''>recent</span> <span style=''>approach</span> <span style=''>that</span> <span style=''>draws</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>considerable</span> <span style='background-color:rgba(0, 255, 0, 0.3441295546558703);'>attention</span> <span style=''>is</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.4166666666666667);'>representation</span> <span style=''>modeling</span> <span style=''>In</span> <span style=''>this</span> <span style=''>model</span> <span style=''>the</span> <span style=''>signal</span> <span style=''>is</span> <span style=''>assumed</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generated</span> <span style=''>as</span> <span style=''>a</span> <span style=''>random</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.32727272727272727);'>combination</span> <span style=''>of</span> <span style=''>a</span> <span style=''>few</span> <span style=''>atoms</span> <span style=''>from</span> <span style=''>a</span> <span style=''>pre</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>specified</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>analyze</span> <span style=''>two</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>denoising</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>the</span> <span style=''>Maximum</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Aposteriori</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Probability</span> <span style=''>(MAP)</span> <span style=''>and</span> <span style=''>the</span> <span style=''>Minimum</span> <span style=''>Mean</span> <span style=''>Squared</span> <span style=''>Error</span> <span style=''>(MMSE)</span> <span style='background-color:rgba(255, 0, 0, 0.6399999999999999);'>estimators</span> <span style=''>under</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assumption</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <span style=''>is</span> <span style=''>unitary</span> <span style=''>It</span> <span style=''>is</span> <span style=''>well</span> <span style=''>known</span> <span style=''>that</span> <span style=''>both</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.6399999999999999);'>estimators</span> <span style=''>lead</span> <span style=''>to</span> <span style=''>a</span> <span style=''>scalar</span> <span style='background-color:rgba(255, 0, 0, 0.8260869565217391);'>shrinkage</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transformed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>coefficients</span> <span style=''>albeit</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3575129533678756);'>different</span> <span style=''>response</sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>liquidSVM</span> <span style=''>A</span> <span style=''>Fast</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Versatile</span> <span style=''>SVM</span> <span style=''>package</span> <br/><br/><span style=''>liquidSVM</span> <span style=''>is</span> <span style=''>a</span> <span style=''>package</span> <span style=''>written</span> <span style=''>in</span> <span style=''>C</span> <span style=''>that</span> <span style=''>provides</span> <span style=''>SVM</span> <span style=''>type</span> <span style=''>solvers</span> <span style=''>for</span> <span style=''>various</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>tasks</span> <span style=''>Because</span> <span style=''>of</span> <span style=''>a</span> <span style=''>fully</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>integrated</span> <span style=''>hyper</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>very</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>carefully</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implemented</span> <span style=''>solvers</span> <span style=''>multi</span> <span style=''>threading</span> <span style=''>and</span> <span style=''>GPU</span> <span style=''>support</span> <span style=''>and</span> <span style=''>several</span> <span style=''>built</span> <span style=''>in</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>strategies</span> <span style=''>it</span> <span style=''>provides</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unprecedented</span> <span style=''>speed</span> <span style=''>for</span> <span style=''>small</span> <span style=''>training</span> <span style=''>sizes</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>for</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>of</span> <span style=''>tens</span> <span style=''>of</span> <span style=''>millions</span> <span style=''>of</span> <span style=''>samples</span> <span style=''>Besides</span> <span style=''>the</span> <span style=''>C</span> <span style=''>API</span> <span style=''>and</span> <span style=''>a</span> <span style=''>command</span> <span style=''>line</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interface</span> <span style=''>bindings</span> <span style=''>to</span> <span style=''>R</span> <span style=''>MATLAB</span> <span style=''>Java</span> <span style=''>Python</span> <span style=''>and</span> <span style=''>Spark</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>brief</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>description</span> <span style=''>of</span> <span style=''>the</span> <span style=''>package</span> <span style=''>and</span> <span style=''>report</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experimental</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>comparisons</span> <span style=''>to</span> <span style=''>other</span> <span style=''>SVM</span> <span style=''>packages</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12202063322660975)
# 	experimental (0.13802917111348276)
# 	architecture (0.08751334044823907)
# 	representation (0.13304873710423337)
# 	processing (0.10885805763073639)
# 	information (0.24119530416221985)
# 	detection (0.12095339736748488)
# 	convolutional (0.13625044468160796)
# 	different (0.27961579509071505)
# 	recognition (0.1383849163998577)
#
# Some Statistics words are:
# 	variational (0.10005027652086476)
# 	estimation (0.16691804927099044)
# 	stochastic (0.13574660633484162)
# 	theoretical (0.1518350930115636)
# 	statistical (0.1533433886375063)
# 	algorithm (0.38009049773755654)
# 	distribution (0.1845148315736551)
# 	inference (0.20261437908496732)
# 	dimensional (0.2016088486676722)
# 	regression (0.18149824032176973)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d0f31968-7f27-43dc-a444-1256d8b0c65d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d0f31968-7f27-43dc-a444-1256d8b0c65d")) {                    Plotly.newPlot(                        "d0f31968-7f27-43dc-a444-1256d8b0c65d",                        [{"x":["realizable","geometric","transitions","distributions","distributed","representations","including","stochastic","properties","depending","probability","submodels","represented","combinatorial","exponential","connections","perspective","approximation","parameters","factorizing","preference","graphical","reflecting","demonstrate","efficient","interpretation","specified","statements","threshold","semantics","elicitation","dependence","generalized","dominance","utilities","representation","advantage","questioning","optimization","conditional","furthermore","underlying","decomposes","computation","functions","procedure","interactive","constraints","experiments","approaches","simulated","complemented","applications","mechanism","dimensional","discovery","structures","interactions","estimation","expression","statistical","theoretical","regression","estimator","guarantees","distribution","additional","increasing","computations","potential","information","introduces","increased","implicitly","recurrent","challenging","convolution","conducted","locations","increases","efficiently","alternative","different","asymptotic","algorithms","minimizes","reasoning","minimization","minimized","algorithm","outperforms","empirically","accumulated","techniques","introducing","cumulative","gradients","descriptive","household","independently","eventually","hierarchical","captioning","exploiting","conditioning","overlapping","interpretable","behaviour","disregards","univariate","variation","regularization","spontaneous","organization","diagnosis","classification","regularized","prediction","framework","activation","typically","important","multivariate","variables","population","classically","principles","behavioural","informative","predictive","extraction","difficult","extracted","dimensionality","parametric","challenge","interpret","structure","functional","selecting","generalization","prioritizing","benchmark","hyperplane","mechanisms","discriminative","classifier","comparable","minimizing","demonstrating","improving","selection","parsimonious","comparison","dimension","importance","complexity","attributes","developing","combination","overfitting","effective","searching","identifying","contributes","vocabulary","described","methodology","compilation","dictionaries","concentration","characteristics","quantitative","perekhresni","following","frequency","correlation","exclusiveness","dictionary","solutions","automatic","characters","advocates","replacing","practical","incomplete","processing","attention","recordings","pipelines","independent","integration","contribution","shortcomings","predictions","competitive","recognition","transcriptions","achieving","intuitive","sequential","magnitude","supplements","represents","ontologies","insufficiency","predicting","insufficient","healthcare","knowledge","diagnoses","electronic","adaptively","additionally","satisfactory","promising","behaviors","challenges","generalizing","performance","optimizing","outperform","estimates","classical","logarithmically","successive","convergence","empirical","dimensions","assumptions","pipelined","relations","experimental","separately","supervision","approximations","expensive","sensitivity","available","generated","computationally","performed","therefore","correspondingly","especially","surrogate","corresponding","establish","significant","numerical","calculation","hypercube","evaluation","objective","relatively","int ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	alliterative
# 	langlands
# 	aerodynamic
# 	preconditioning
# 	injecting
# 	minimality
# 	astrophysics
# 	microwave
# 	discretised
# 	strongest
# 	timescales
# 	inclusions
# 	geosciences
# 	repeatmulti
# 	statisticians
# 	algebraically
# 	overdetermined
# 	tsybakovs
# 	technically
# 	eliciting
# Some words which never appear in Statistics papers:
# 	disregards
# 	spontaneous
# 	compilation
# 	perekhresni
# 	exclusiveness
# 	transcriptions
# 	pipelined
# 	actuation
# 	satisfiability
# 	afterwards
# 	immediate
# 	withdrawn
# 	relighting
# 	eligibility
# 	fundament
# 	reflection
# 	trigonometric
# 	unaffected
# 	interference
# 	quantizing

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0581039755351684e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7591666666666667
